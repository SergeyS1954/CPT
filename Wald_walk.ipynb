# %% [markdown]
# <a href="https://colab.research.google.com/github/SergeyS1954/CPT/blob/main/Wald_walk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
alpha = 0.1
beta = 0.1
theta0 = 0
theta1 = 0.5
sigma2 = 2.0
size = 100
#generate random aray
np.random.seed(1235)
arr_1 = np.random.normal(theta0, sigma2, size)
#bounds
a_0  = (sigma2/(theta1 - theta0))*np.log(beta/(1 - alpha))
a_1  = (sigma2/(theta1 - theta0))*np.log((1 - beta)/alpha)
sum = 0
theta = theta0 + theta1
h0 = 0
h1 = 0
s1 = []
s = 0
#main loop
for i in range(size):
    s = sum - i/2*theta
    s1.append(sum - i/2*theta)
    if s < a_0 :
        h0 = 1
        break
    if s > a_1 :
        h1 = 1
        break
    else : i = i + 1
    sum = sum + arr_1[i]
#print (' i = ', i, 'h0 = ', h0, 'h1 = ', h1)
#plt.figure(figsize=(12, 6))
x = np.linspace(0,i+1,i+1)
plt.plot(x, s1, label='S1')
plt.plot(x, np.linspace(a_0,a_0,i+1), label='a_0')
plt.plot(x, np.linspace(a_1,a_1,i+1), label='a_1')
plt.legend()
plt.ylabel("Значение статистики")
plt.xlabel('Объем выборки')
plt.title("Процедура Вальда как случайное блуждание")
plt.grid()
plt.show()
